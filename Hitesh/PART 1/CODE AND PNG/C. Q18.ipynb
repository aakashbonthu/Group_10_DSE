# %%
# QUESTION FROM SECTION C .Trend and Visual Analytics

# 18.Create a simple table showing the latest available value for Brent Oil, Gold and Silver. 

import os
import matplotlib.pyplot as plt

# Create folder
save_folder = r"E:\UE class schedule\DATA SCIENCE\DSB Project\Tables"
os.makedirs(save_folder, exist_ok=True)

# Save CSV with Q number
latest_values_table.to_csv(
    os.path.join(save_folder, "Q18_Latest_Values_Table.csv"),
    index=False
)

# Convert table to PNG
fig, ax = plt.subplots(figsize=(8, 2))
ax.axis('off')

table = ax.table(
    cellText=latest_values_table.values,
    colLabels=latest_values_table.columns,
    cellLoc='center',
    loc='center'
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)

# Save PNG with Q number
plt.savefig(
    os.path.join(save_folder, "Q18_Latest_Values_Table.png"),
    bbox_inches='tight',
    dpi=300
)

plt.close()

plt.close()

# Display table in Jupyter Notebook
from IPython.display import display

print("Q18: Latest Values Table")
display(latest_values_table)

print("Q18 table saved successfully!")
# Out:
# Q18: Latest Values Table
#    Commodity Latest Date  Latest Value
# 0  Brent Oil  03/01/2026      102.8600
# 1       Gold  04/01/2026     4712.8906
# 2     Silver  04/01/2026       88.3600
# Q18 table saved successfully!
